# %% [markdown]
# # Setup

# %%
import torch
import utils

# %% [markdown]
# # Detect

# %%
# !python yolov5/detect.py --weights best11.pt --img 640 --conf-thres 0.75 --source eval_folder_ --save-txt
# Out:
# detect: weights=['best11.pt'], source=eval_folder_, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.75, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-284-g95ebf68f Python-3.11.4 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/10264 /common/home/users/d/dariustay.2022/eval_folder_/000000.jpg: 640x640 (no detections), 9.2ms
# image 2/10264 /common/home/users/d/dariustay.2022/eval_folder_/000001.jpg: 640x640 (no detections), 9.2ms
# ...
